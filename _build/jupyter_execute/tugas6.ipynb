# %%
# PENYEIMBANGAN DATA MENGGUNAKAN SMOTE DAN ADASYN

# %% [markdown]
#  ### Menginstall Library

# %% [markdown]
# ###

# %%
pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (0.14.0)
# Requirement already satisfied: numpy<3,>=1.25.2 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from imbalanced-learn) (1.26.4)
# Requirement already satisfied: scipy<2,>=1.11.4 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from imbalanced-learn) (1.11.4)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: joblib<2,>=1.2.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from imbalanced-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from imbalanced-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

df = pd.read_csv("ecoli_original.csv")

print("Info dataset:")
print(df.info())
print("\nCek nilai kosong:")
print(df.isnull().sum())

X = df.drop(columns=['sequence_name','class'])
y = df['class']

X.to_csv("ecoli_features.csv", index=False)
y.to_csv("ecoli_labels.csv", index=False)
print("\nData numerik & label sudah dipisah.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv("ecoli_original.csv")
#       5 print("Info dataset:")
#       6 print(df.info())
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)    944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ecoli_original.csv'

# %%
import pandas as pd

df = pd.read_csv("ecoli_original.csv")

print("Info dataset:")
print(df.info())
print("\nCek nilai kosong:")
print(df.isnull().sum())

X = df.drop(columns=['sequence_name','class'])
y = df['class']

X.to_csv("ecoli_features.csv", index=False)
y.to_csv("ecoli_labels.csv", index=False)
print("\nData numerik & label sudah dipisah.")

# %%
import pandas as pd
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

X = pd.read_csv("ecoli_features.csv")
y = pd.read_csv("ecoli_labels.csv").squeeze() 

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

plt.figure(figsize=(8,6))
scatter = plt.scatter(X_pca[:,0], X_pca[:,1],
                       c=pd.factorize(y)[0],
                       cmap='tab10', alpha=0.8)
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("Ecoli Data - PCA Original")
plt.legend(scatter.legend_elements()[0], pd.factorize(y)[1], bbox_to_anchor=(1.05,1))
plt.tight_layout()
plt.show()

# %%
import pandas as pd
from imblearn.over_sampling import ADASYN

X = pd.read_csv("ecoli_features.csv")
y = pd.read_csv("ecoli_labels.csv").squeeze()

adasyn = ADASYN(random_state=42)
X_res, y_res = adasyn.fit_resample(X, y)

print("Distribusi Kelas Sebelum:")
print(y.value_counts())
print("\nDistribusi Kelas Sesudah ADASYN:")
print(pd.Series(y_res).value_counts())

X_res.to_csv("ecoli_features_balanced.csv", index=False)
pd.Series(y_res).to_csv("ecoli_labels_balanced.csv", index=False)
print("\nData hasil ADASYN disimpan.")

# %%
import pandas as pd
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

X_res = pd.read_csv("ecoli_features_balanced.csv")
y_res = pd.read_csv("ecoli_labels_balanced.csv").squeeze()

pca = PCA(n_components=2)
X_res_pca = pca.fit_transform(X_res)

plt.figure(figsize=(8,6))
scatter = plt.scatter(X_res_pca[:,0], X_res_pca[:,1],
                       c=pd.factorize(y_res)[0],
                       cmap='tab10', alpha=0.8)
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("Ecoli Data - PCA After ADASYN")
plt.legend(scatter.legend_elements()[0], pd.factorize(y_res)[1], bbox_to_anchor=(1.05,1))
plt.tight_layout()
plt.show()
